# %%
import pandas as pd 
customers=pd.read_csv('../Staging_1/customers/customers.csv')
customers.head()
# Out:
#    customer_id  first_name last_name           phone                    email  \
# 0            1       Debra     Burks    not recorded    debra.burks@yahoo.com
# 1            2       Kasha      Todd    not recorded     kasha.todd@yahoo.com
# 2            3      Tameka    Fisher    not recorded    tameka.fisher@aol.com
# 3            4       Daryl    Spence    not recorded     daryl.spence@aol.com
# 4            5  Charolette      Rice  (916) 381-6003  charolette.rice@msn.com
#
#                   street           city state  zip_code  \
# 0      9273 Thorne Ave.    Orchard Park    NY     14127
# 1       910 Vine Street        Campbell    CA     95008
# 2  769C Honey Creek St.   Redondo Beach    CA     90278
# 3        988 Pearl Lane       Uniondale    NY     11553
# 4         107 River Dr.      Sacramento    CA     95820
#
#                  extract_time    source
# 0  2024-04-28 19:23:08.863341  datalake
# 1  2024-04-28 19:23:08.863341  datalake
# ...

# %%
stores=pd.read_csv('../Staging_1/stores/stores.csv')
stores.head()
# Out:
#    store_id        store_name           phone               email  \
# 0         1  Santa Cruz Bikes  (831) 476-4321            no email
# 1         2     Baldwin Bikes  (516) 379-8888  baldwin@bikes.shop
# 2         3     Rowlett Bikes  (972) 530-5555  rowlett@bikes.shop
#
#                 street        city state     zip_code  \
# 0   3700 Portola Drive  Santa Cruz    CA  no zip_code
# 1   4200 Chestnut Lane     Baldwin    NY      11432.0
# 2  8000 Fairway Avenue     Rowlett    TX      75088.0
#
#                  extract_time    source
# 0  2024-04-28 19:25:45.322157  datalake
# 1  2024-04-28 19:25:45.322157  datalake
# 2  2024-04-28 19:25:45.322157  datalake

# %%
store_cities = set(stores['city'].unique())
customers['local'] = customers['city'].apply(lambda x: x in store_cities)
customers
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks    not recorded
# 1               2       Kasha      Todd    not recorded
# 2               3      Tameka    Fisher    not recorded
# 3               4       Daryl    Spence    not recorded
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison    not recorded
# 1441         1442      Cassie     Cline    not recorded
# 1442         1443      Lezlie      Lamb    not recorded
# 1443         1444      Ivette     Estes    not recorded
# 1444         1445       Ester   Acevedo    not recorded
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
customers.to_csv('../Staging_2/customers/customers.csv', index=False)
